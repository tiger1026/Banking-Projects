# %%
# import libraries
import numpy as np
import pandas as pd
import itertools
from datetime import datetime
import time
import math
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score
from lightgbm import LGBMClassifier
from tqdm import tqdm
from contextlib import contextmanager
import gc
import re
import string

# %%
test = pd.read_csv(r"C:\Users\120200\Desktop\Product Recommendation-Tiger\Train\B360_202106_10Percent_DawhoOnly.csv")
test_dict = test.to_dict()

# %%
test.columns.tolist()
# Out:
# ['資料年月',
#  '身分證字號',
#  '性別',
#  '年齡',
#  '生日月份',
#  '客戶年收入',
#  '客戶行業別',
#  '客戶職稱',
#  'ELOAN職稱',
#  '最初開戶日',
#  '往來期間(月)',
#  '最近交易日',
#  '最近交易期間(月)',
#  '最後通聯日',
#  '員工記號',
#  '金控員工記號(非銀行)',
#  '投資屬性',
#  '尊榮理財會員等級',
#  '信用卡VIP客戶註記',
#  '對帳單寄送記號',
#  '網易收會員記號',
#  '網路使用記號',
#  '網路使用記號-行動銀行',
#  '網路服務記號',
#  '網路會員記號',
#  'ibrAin記號',
#  'MMA+記號',
#  'MMA記號',
#  '小mma記號',
#  'MMA標會網客戶記號',
#  '數位帳戶記號',
#  '豐掌櫃會員記號',
#  '薪轉公司統編',
#  '薪轉戶記號(三個月)',
#  '專業投資人記號',
#  '秘密戶記號',
#  '拒絕往來戶記號',
#  '催收記號',
#  '呆帳記號',
#  '存款記號',
#  '外幣存款記號',
#  '外幣活存記號',
#  '美金存款註記',
#  '人民幣存款註記',
#  '歐元存款註記',
#  '澳幣存款註記',
#  '南非幣存款註記',
#  '放款記號',
#  '房貸記號',
#  '信貸記號',
#  '信託記號',
#  '信用卡記號',
#  '人身保險記號',
#  '產險記號',
#  '壽險理財金記號',
#  '證券記號',
#  '證券推介開戶記號',
#  '銀行推介(證券端記號)記號',
#  '黃金存摺戶記號',
#  '銀行電話銷售記號',
#  '保管箱記號',
#  '保證人記號',
#  '保管箱租金',
#  '主經管人員',
#  '共同行銷／合作推廣（人保）',
#  '共同行銷／合作推廣（證券）',
#  '個金放款型客戶',
#  '個保法記號',
#  '特定金錢信託客戶投資有價證券推介同意書',
#  '最近逾期記號',
#  '通訊地址失聯記號',
#  '台外幣總存款',
#  '台幣支存總餘額',
#  '台幣定存總餘額',
#  '台幣定期性總存款',
#  '台幣定儲總餘額',
#  '台幣活存總餘額',
#  '台幣活期性總存款',
#  '台幣總存款',
#  '外幣存單最近三個月平均餘額',
#  '外幣定期性總存款',
#  '外幣活期性總存款',
#  '外幣總存款',
#  '存單最近到期日',
#  '存單最近到期金額',
#  '存款最近交易日',
#  '存款開戶日',
#  '定期性存款12個月期以上(台幣)',
#  '定期性存款12個月期以上(外幣)',
#  '定期性存款1至2個月期(台幣)',
#  '定期性存款3至5個月期(台幣)',
#  '定期性存款6至11個月期(台幣)',
#  '定期性存款近一季未到期總餘額(台幣)',
#  '定期性存款近一季未到期總餘額(外幣)',
#  '定期性存款近一季到期總餘額(台幣)',
#  '定期性存款近一季到期總餘額(外幣)',
#  '黃金庫存部位(依月底日牌價折算台幣)',
#  '當年度保險佣金金額(要保人)',
#  '當年度保險佣金金額(被保人)',
#  'ETF投資現值',
#  'ETF近12個月申購次數',
#  'ETF近12個月申購金額',
#  'ETF近1個月申購次數',
#  'ETF近1個月申購金額',
#  '佣金金額',
#  '投資型保險申購記號(要保人)',
#  '投資型保險申購記號(被保人)',
#  '定時定額記號',
#  '房貸壽險申購記號(要保人)',
#  '房貸壽險申購記號(被保人)',
#  '保單張數(被保人)',
#  '保險-要保人記號',
#  '保險-被保人記號',
#  '信用戶開戶日期',
#  '信用戶融券額度',
#  '信用戶融資額度',
#  '信託投資金額',
#  '信託投資現值',
#  '信託帳戶開戶日',
#  '信託第一筆申購日',
#  '信託最近交易日',
#  '家庭保障險申購記號(要保人)',
#  '家庭保障險申購記號(被保人)',
#  '庫存股股數',
#  '庫存股檔數',
#  '海外債券投資現值',
#  '海外債券近12個月申購次數',
#  '海外債券近1個月申購金額',
#  '海外債券近6個月申購金額',
#  '現股庫存市值',
#  '產險-要保人記號',
#  '累計佣金金額(要保人)',
#  '累計佣金金額(被保人)',
#  '累計實收保費(被保人)',
#  '單筆申購記號',
#  '單筆申購基金結清憑證平均持有天數',
#  '最近一次應繳日(要保人)',
#  '最近一個月平均信託投資金額',
#  '最近三個月平均信託投資金額',
#  '當月佣金金額(被保人)',
#  '當月國內基金申購手續費',
#  '當月基金申購手續費',
#  '當月境外基金申購手續費',
#  '當月實收保費(要保人)',
#  '當月實收保費(被保人)',
#  '當年度累計實收保費(要保人)',
#  '當年度累計實收保費(被保人)',
#  '融券使用金額',
#  '融券庫存市值',
#  '融資三月交易額',
#  '融資六月交易額',
#  '融資月交易額',
#  '融資年交易額',
#  '融資使用金額',
#  '融資庫存市值',
#  '儲蓄養老險申購記號(要保人)',
#  '儲蓄養老險申購記號(被保人)',
#  '證券月交易筆數',
#  '證券月交易額',
#  '證券最近交易日',
#  '證券開戶日',
#  '一般房貸利率',
#  '房貸開戶日',
#  '放款往來期間(月)',
#  '放款最近交易日',
#  '放款最近交易期間(月)',
#  '放款結清戶日期',
#  '放款結清戶記號',
#  '放款開戶日',
#  '放款總餘額',
#  '放款總餘額  一般房貸(36)',
#  '放款總餘額房貸',
#  '放款總餘額  信貸(41_42)',
#  '放款總餘額  個人信用貸款(42)',
#  '放款總餘額  理財房貸(34_35_47)',
#  '信貸開戶日',
#  '活期領用平均使用率',
#  '活期領用餘額',
#  '活期領用額度',
#  '理財房貸利率(LINE)',
#  '理財房貸利率(LN)',
#  '理財房貸近一月透支領用使用額度',
#  '理財房貸近六月透支領用使用額度',
#  '理財房貸透支領用額度',
#  '理財房貸額度近三月平均使用率',
#  '理財房貸額度近六月平均使用率',
#  '理財型房貸記號',
#  '理財型房貸透支領用餘額(月底日)',
#  '結清戶撥款金額',
#  '撥款總額',
#  '撥款總額 一般房貸(36)',
#  '撥款總額房貸',
#  '撥款總額 信貸(41_42)',
#  '撥款總額 個人信用貸款(42)',
#  '撥款總額 理財房貸(34_35_47)',
#  '總放款平均利率',
#  '還款率',
#  '轉呆帳餘額',
#  '轉催收餘額',
#  '自動扣款記號',
#  '住宅記號',
#  '信用卡開戶日',
#  '信用卡逾期紀錄',
#  '信用卡職位別',
#  '信用卡轉呆記號',
#  '信用循環戶記號',
#  '信用評等資料-中擔餘額',
#  '信用評等資料-長擔餘額',
#  '信用評等資料-信貸餘額',
#  '最近一個月M2次數',
#  '最近一個月刷卡數',
#  '最近一個月預借現金次數',
#  '最近六個月M2次數',
#  '最近六個月預借現金次數',
#  '電子化通路記號',
#  '預借現金額度(仟元)',
#  '總應收帳款(含未結帳部份)(元)',
#  '應收帳款承購(額度)',
#  '應收帳款收買',
#  '分行別',
#  '企業客戶AP',
#  '企金行業別',
#  '企審催收記號',
#  '公司戶記號',
#  '企業客戶年度AP',
#  '信用卡—最近一個月收單手續費收入(元)',
#  '信保記號',
#  'SI/DCI投資未到期金額(外幣)',
#  'SI/DCI投資未到期金額(台幣)',
#  'SI/DCI投資未到期總金額',
#  'SI/DCI近1個月申購金額(外幣)',
#  'SI/DCI近1個月申購金額(台幣)',
#  'SI/DCI近1個月申購次數',
#  'SI/DCI近12個月申購金額(外幣)',
#  'SI/DCI近12個月申購金額(台幣)',
#  'SI/DCI近12個月申購次數',
#  'SI/DCI近12個月申購總金額',
#  'SI/DCI近1個月申購總金額',
#  '有效主卡張數',
#  'ETF近6個月申購次數',
#  'ETF記號',
#  '永久信用額度(仟元)',
#  '理財房貸近三月透支領用使用額度',
#  '有擔保額度',
#  '最近十二個月平均餘額(外幣總存款)',
#  '最近十二個月平均餘額(台幣活期性總存款)',
#  '最近十二個月M2次數',
#  '最近十二個月收單金額(元)',
#  '最近一個月平均消費額(元)',
#  '最近一個月消費額(元)',
#  '最近一個月一般消費刷卡金額(元)',
#  '最近一個月預借現金金額(元)',
#  '最近一個月收單金額(元)',
#  '最近一年平均餘額 (台外幣總存款)',
#  '最近一年平均餘額 (台幣支存)',
#  '最近一年平均餘額 (外幣活期總存款)',
#  '最近一年平均餘額(台幣活存)',
#  '最近一年平均餘額(台幣定期性存款)',
#  '最近三個月平均餘額(台外幣總存款)',
#  '最近三個月平均餘額(台幣活儲)',
#  '最近三個月平均餘額(外幣活期總存款)',
#  '最近三個月平均餘額(台幣定期性存款)',
#  '最近三個月平均餘額(台幣總存款)',
#  '最近三個月平均餘額(外幣總存款)',
#  '最近三個月平均餘額(台幣活期性總存款)',
#  '最近三個月平均消費額(元)',
#  '最近三個月消費額(元)',
#  '最近三個月一般消費刷卡金額(元)',
#  '最近三個月刷卡數',
#  '最近六個月平均餘額(台外幣總存款)',
#  '最近六個月平均餘額(台幣活儲)',
#  '最近六個月平均餘額(台幣活存)',
#  '最近六個月平均餘額(外幣總存款)',
#  '最近六個月平均餘額(台幣活期性總存款)',
#  '最近六個月平均消費額(元)',
#  '最近六個月消費額(元)',
#  '最近六個月一般消費刷卡金額(元)',
#  '最近六個月預借現金金額(元)',
#  '最近六個月收單金額(元)',
#  '最近三個月平均餘額(台幣活存)',
#  '最近六個月平均餘額(外幣活期總存款)',
#  '授信餘額',
#  '授信總金額',
#  '主戶ID',
#  '網路預借現金-(MMA+信用卡網路預現)(元)',
#  '無擔保額度',
#  '目前可用額度(元)',
#  '負責人身份證字號',
#  '業績統計用資產規模(含家族戶)',
#  '業績統計用資產規模(新)-近三個月平均',
#  '電話１(戶籍)失聯記號',
#  '電話２(住家)失聯記號',
#  '電話４(公司)失聯記號',
#  '電話５(行動)失聯記號',
#  '電話８(其他)失聯記號',
#  '額度動用率',
#  '關係戶記號',
#  '薪轉代理編號',
#  '薪轉代理編號取號日',
#  'SI/DCI記號',
#  '中小企業記號(Y/N)',
#  'SN近1個月申購金額',
#  'SN近6個月申購金額',
#  'SN記號',
#  '證券近一年交易額',
#  '證券近一年交易筆數',
#  '證券近三個月交易額',
#  '證券近六個月交易額',
#  '停滯戶記號',
#  'CIFAOCODE',
#  '數位帳戶等級記號',
#  '當月總AP合計',
#  '當月存款總AP',
#  '當月台幣存款AP',
#  '當月台幣活期性存款AP',
#  '當月台幣定期性存款AP',
#  '當月外幣存款AP',
#  '當月外幣活期性存款AP',
#  '當月外幣定期性存款AP',
#  '當月授信總AP',
#  '當月房貸AP',
#  '當月車貸AP',
#  '當月信貸AP',
#  '當月個金其他放款AP',
#  '當月法金放款AP',
#  '當月投資理財總AP',
#  '當月基金AP',
#  '當月(ETF)AP',
#  '當月債券AP',
#  '當月(SN)AP',
#  '當月(ibrAin)AP',
#  '當月(SI/DCI)AP',
#  '當月黃金存摺AP',
#  '當月其他金融商品AP',
#  '當月人身保險總AP',
#  '當月人身保險(投資型)AP',
#  '當月人身保險(家庭保障)AP',
#  '當月人身保險(儲蓄養老)AP',
#  '當月人身保險(房貸壽險)AP',
#  '當月財產保險總AP',
#  '當月財產保險(汽機車保險)AP',
#  '當月財產保險(住宅火險)AP',
#  '當月財產保險(商業險)AP',
#  '當月財產保險(傷害險+健康險)AP',
#  '當月信用卡總AP',
#  '當月信用卡AP',
#  '當月信用卡收單AP',
#  '當月(Debit Card)AP',
#  '當月金流總AP',
#  '當月外匯總AP',
#  '當年度總AP合計',
#  '當年度存款總AP',
#  '當年度台幣存款AP',
#  '當年度台幣活期性存款AP',
#  '當年度台幣定期性存款AP',
#  '當年度外幣存款AP',
#  '當年度外幣活期性存款AP',
#  '當年度外幣定期性存款AP',
#  '當年度授信總AP',
#  '當年度房貸AP',
#  '當年度車貸AP',
#  '當年度信貸AP',
#  '當年度個金其他放款AP',
#  '當年度法金放款AP',
#  '當年度投資理財總AP',
#  '當年度基金AP',
#  '當年度(ETF)AP',
#  '當年度債券AP',
#  '當年度(SN)AP',
#  '當年度(ibrAin)AP',
#  '當年度(SI/DCI)AP',
#  '當年度黃金存摺AP',
#  '當年度其他金融商品AP',
#  '當年度人身保險總AP',
#  '當年度人身保險(投資型)AP',
#  '當年度人身保險(家庭保障)AP',
#  '當年度人身保險(儲蓄養老)AP',
#  '當年度人身保險(房貸壽險)AP',
#  '當年度財產保險總AP',
#  '當年度財產保險(汽機車保險)AP',
#  '當年度財產保險(住宅火險)AP',
#  '當年度財產保險(商業險)AP',
#  '當年度財產保險(傷害險+健康險)AP',
#  '當年度信用卡總AP',
#  '當年度信用卡AP',
#  '當年度信用卡收單AP',
#  '當年度(Debit Card)AP',
#  '當年度金流總AP',
#  '當年度外匯總AP',
#  '業績統計用資產規模(新)',
#  '最近一個月平均餘額(台外幣總存款)',
#  '最近一個月平均餘額(台幣總存款)',
#  '最近一個月平均餘額(台幣活期性存款)',
#  '最近一個月平均餘額(台幣定期性存款)',
#  '最近一個月平均餘額(外幣總存款)',
#  '最近一個月平均餘額(外幣活期性存款)',
#  '最近一個月平均餘額(外幣定期性存款)',
#  '最近一個月平均餘額(總投資理財)',
#  '最近一個月平均餘額(基金)',
#  '最近一個月平均餘額(國內非貨幣型基金)',
#  '最近一個月平均餘額(國內貨幣型基金)',
#  '最近一個月平均餘額(境外基金)',
#  '最近一個月平均餘額(ETF)',
#  '最近一個月平均餘額(債券)',
#  '最近一個月平均餘額(SN)',
#  '最近一個月平均餘額(ibrAin)',
#  '最近一個月平均餘額(SI/DCI)',
#  '最近一個月平均餘額(黃金存摺)',
#  '最近一個月平均餘額(RP)',
#  '最近一個月平均餘額(RS)',
#  '最近一個月平均餘額(總人身保險)',
#  '最近一個月平均餘額(人身保險-投資型)',
#  '最近一個月平均餘額(人身保險-家庭保障)',
#  '最近一個月平均餘額(人身保險-儲蓄養老)',
#  '最近一個月平均餘額(人身保險-房貸壽險)',
#  '存款持有',
#  '台幣存款持有',
#  '外幣存款持有',
#  '授信持有',
#  '房貸持有',
#  '車貸持有',
#  '信貸持有',
#  '個金其他放款持有',
#  '法金放款持有',
#  '投資理財持有',
#  '基金持有',
#  'ETF持有',
#  '債券持有',
#  'SN持有',
#  'ibrAin持有',
#  'SI/DCI持有',
#  '黃金存摺持有',
#  'RP持有',
#  'RS持有',
#  '其他金融商品持有',
#  '人身保險持有',
#  '人身保險(投資型)持有',
#  '人身保險(家庭保障)持有',
#  '人身保險(儲蓄養老)持有',
#  '人身保險(房貸壽險)持有',
#  '財產保險持有',
#  '財產保險(汽機車保險)持有',
#  '財產保險(住宅火險)持有',
#  '財產保險(商業險)持有',
#  '財產保險(傷害險+健康險)持有',
#  '信用卡持有',
#  '信用卡(信用卡)持有',
#  '信用卡收單持有',
#  'Debit Card持有',
#  '金流持有',
#  '外匯持有',
#  '存款使用',
#  '台幣存款使用',
#  '外幣存款使用',
#  '授信使用',
#  '房貸使用',
#  '車貸使用',
#  '信貸使用',
#  '個金其他放款使用',
#  '法金放款使用',
#  '投資理財使用',
#  '基金使用',
#  'ETF使用',
#  '債券使用',
#  'SN使用',
#  'ibrAin使用',
#  'SI/DCI使用',
#  '黃金存摺使用',
#  'RP使用',
#  'RS使用',
#  '其他金融商品使用',
#  '人身保險使用',
#  '人身保險(投資型)使用',
#  '人身保險(家庭保障)使用',
#  '人身保險(儲蓄養老)使用',
#  '人身保險(房貸壽險)使用',
#  '財產保險使用',
#  '財產保險(汽機車保險)使用',
#  '財產保險(住宅火險)使用',
#  '財產保險(商業險)使用',
#  '財產保險(傷害險+健康險)使用',
#  '信用卡使用',
#  '信用卡(信用卡)使用',
#  '信用卡收單使用',
#  'Debit Card使用',
#  '金流使用',
#  '外匯使用',
#  '全行往來產品數(持有1階)',
#  '全行往來產品數(持有2階)',
#  '全行往來產品數(使用1階)',
#  '全行往來產品數(使用2階)',
#  '最近一個月總ROA',
#  '最近一年總ROA',
#  '最近一個月理財ROA',
#  '最近一年理財ROA',
#  '最近一個月特金ROA',
#  '最近一年特金ROA',
#  '最近一個月授信ROA',
#  '最近一年授信ROA',
#  '客群面向_財管客戶註記',
#  '客群面向_潛力財管客戶註記',
#  '客群面向_薪轉客戶註記',
#  '客群面向_大戶客戶註記',
#  '當月新開大戶',
#  'Line_好友狀態',
#  'Line_綁定狀態',
#  'Line_第一次綁定時間',
#  'Line_最後綁定時間',
#  'Line_是否存戶',
#  'Line_是否卡戶',
#  'Line_是否是新好友',
#  'Line_是否是新綁定',
#  'Line_是否近30日流失',
#  'Line_是否曾封鎖',
#  'Line_是否曾綁定',
#  'Line_是否曾解綁',
#  'Line_第一次加好友時間',
#  'Line_好友狀態異動時間',
#  'Line_近30日與LINE官方互動的次數',
#  'Line_互動程度',
#  'Line_近30日有關鍵字點擊行為',
#  'Line_近30日有URL點擊行為',
#  'Line_是否訂閱服務',
#  'Line_服務訂閱_信用卡刷卡',
#  'Line_服務訂閱_行動帳單',
#  'Line_服務訂閱_匯率到價',
#  'Line_服務訂閱_生活金融',
#  'Line_服務訂閱_刷卡回饋',
#  'Line_服務訂閱_大戶數位帳戶',
#  'Line_服務訂閱_永豐ibrAin',
#  'Line_服務訂閱_更多優惠',
#  'Line_服務訂閱_定存到期通知',
#  'Line_服務訂閱_薪轉入帳通知',
#  '當月基金申購金額',
#  '婚姻',
#  'DMP_外幣定存',
#  'DMP_台幣定存',
#  'DMP_兒童帳戶',
#  'DMP_信貸or他行信貸還款',
#  'DMP_理財型房貸',
#  'DMP_二順位房貸',
#  'DMP_房貸',
#  'DMP_汽車貸款',
#  'DMP_信用卡_保倍卡',
#  'DMP_信用卡_DAWHO現金回饋Debit卡',
#  'DMP_信用卡_DAWHO現金回饋卡',
#  'DMP_信用卡_MeCard',
#  'DMP_信用卡_Sport_debit卡',
#  'DMP_信用卡_VOGUE卡',
#  'DMP_信用卡_三井卡',
#  'DMP_信用卡_中興大學悠遊認同卡',
#  'DMP_信用卡_永豐世界卡',
#  'DMP_信用卡_永豐美麗華卡',
#  'DMP_信用卡_永豐財富無限卡',
#  'DMP_信用卡_永豐運動卡',
#  'DMP_信用卡_東森網連通聯名卡',
#  'DMP_信用卡_活動登錄',
#  'DMP_信用卡_活動關注',
#  'DMP_信用卡_美安聯名卡',
#  'DMP_信用卡_美樂家生活卡',
#  'DMP_信用卡_財富無限/世界虛擬卡',
#  'DMP_信用卡_國民旅遊卡',
#  'DMP_信用卡_國際學生證Debit卡',
#  'DMP_信用卡_現金回饋debit卡',
#  'DMP_信用卡_現金回饋卡',
#  'DMP_信用卡_現金回饋虛擬卡',
#  'DMP_信用卡_鈦豐卡',
#  'DMP_信用卡_夢行卡',
#  'DMP_信用卡_幣倍卡',
#  'DMP_信用卡_興大分行限定版Debit卡',
#  'DMP_信用卡_醫療or保險',
#  'DMP_效率投資法',
#  'DMP_定時定額',
#  'DMP_安養信託',
#  'DMP_保險金信託',
#  'DMP_有價證券出借信託',
#  'DMP_有價證券贈與信託',
#  'DMP_不動產信託(管理型)',
#  'DMP_遺囑信託',
#  'DMP_員工獎酬信託',
#  'DMP_不動產開發信託',
#  'DMP_財產交易安全信託',
#  'DMP_公益信託',
#  'DMP_全權委託投資保管',
#  'DMP_外資保管',
#  'DMP_公司債受託',
#  'DMP_有價證券簽證',
#  'DMP_預收款信託',
#  'DMP_大戶DAWHO',
#  '近六個月未登入數位平台',
#  '存款最早開戶日',
#  '台幣活存持有帳號數',
#  '台幣活存使用帳號數',
#  '台幣活儲持有帳號數',
#  '台幣活儲使用帳號數',
#  '台幣定儲_存本取息',
#  '台幣定儲_整存整付',
#  '台幣定儲_零存整付',
#  '外幣活期持有帳號數',
#  '外幣活期使用帳號數',
#  '美金活期折台',
#  '人民幣活期折台',
#  '美金定期折台',
#  '人民幣定期折台',
#  '近三個月網銀使用記號',
#  '近三個月Mobile使用記號',
#  '近三個月大戶app使用記號',
#  '庫存基金原始投資金額',
#  '庫存ETF原始投資金額',
#  '庫存ibrain原始投資金額',
#  '網銀轉帳備註_公共事業費',
#  '網銀轉帳備註_手機電話費',
#  '網銀轉帳備註_代購',
#  '網銀轉帳備註_外幣',
#  '網銀轉帳備註_生活開支',
#  '網銀轉帳備註_交通費',
#  '網銀轉帳備註_地價稅',
#  '網銀轉帳備註_投資',
#  '網銀轉帳備註_車貸',
#  '網銀轉帳備註_房屋稅',
#  '網銀轉帳備註_房租',
#  '網銀轉帳備註_房貸',
#  '網銀轉帳備註_所得稅',
#  '網銀轉帳備註_直銷',
#  '網銀轉帳備註_股票',
#  '網銀轉帳備註_保險',
#  '網銀轉帳備註_信用卡',
#  '網銀轉帳備註_信貸',
#  '網銀轉帳備註_借貸周轉',
#  '網銀轉帳備註_娛樂費用',
#  '網銀轉帳備註_家用(給家人)',
#  '網銀轉帳備註_旅遊',
#  '網銀轉帳備註_基金',
#  '網銀轉帳備註_勞健保',
#  '網銀轉帳備註_期貨',
#  '網銀轉帳備註_牌照稅',
#  '網銀轉帳備註_貸款',
#  '網銀轉帳備註_電商購物',
#  '網銀轉帳備註_實體商店購物',
#  '網銀轉帳備註_管理費',
#  '網銀轉帳備註_學貸',
#  '網銀轉帳備註_燃料稅',
#  '網銀轉帳備註_營業稅',
#  '網銀轉帳備註_薪資',
#  '網銀轉帳備註_繳稅']

# %%
test_dict['new column'] = test_dict['最近一個月總ROA']

# %%
test_dict['new column'] == test_dict['最近一個月總ROA']
# Out:
# True
